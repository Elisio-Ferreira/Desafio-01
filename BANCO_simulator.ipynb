# %% [markdown]
# <a href="https://colab.research.google.com/github/Elisio-Ferreira/Desafio-01/blob/main/BANCO_simulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('--- BANCO LILIZA ---\n')
print('--- SELECIONE UMA OPÇÃO ---\n')

print('[1] - Depositar')
print('[2] - Sacar')
print('[3] - Extrato \n')

valor_Total = []
valor_deposito = []
valor_saque = []

op = int(input('OPÇÃO DESEJADA:  \n'))

print('VOÇE ESCOLHEU A OPCAO:  ', op)


if op == 1:
    print('HORA DE DEPOSITAR \n')
    valor_deposito = int(input('QUAL VALOR DO DEPOSITO \n'))
    print('VOCE REALIZOU UM DEPOSITO DE: ', valor_deposito)
    valor_Total.append(valor_deposito)
    print(valor_Total[0])
# Out:
# --- BANCO LILIZA ---
#
# --- SELECIONE UMA OPÇÃO ---
#
# [1] - Depositar
# [2] - Sacar
# [3] - Extrato
#
# OPÇÃO DESEJADA:
# 1
# VOÇE ESCOLHEU A OPCAO:   1
# HORA DE DEPOSITAR
#
# QUAL VALOR DO DEPOSITO
# 100
# VOCE REALIZOU UM DEPOSITO DE:  100
# 100
